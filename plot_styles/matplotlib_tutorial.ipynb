# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Legends title and labels

x = [1, 2, 3]
y = [3, 5, 2]
y2 = [4, -1., 3]
y3 = [1, 4., -2]
plt.title('Linear couplings')
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim([0.95,3.05])
plt.ylim([-2,6])
plt.grid()
plt.xticks(np.arange(1,3.5,step=1.0))
plt.yticks(np.arange(-2,6,step=2),('low','medium','high','very high'),rotation='30')
plt.plot(x, y, label='y',marker='^',color='k')
plt.plot(x, y2, label='y2',marker='o',color='r')
plt.plot(x, y3, label='y3',marker='s',color='b',linestyle='--',linewidth=1)
plt.legend()
plt.show()

# %%
# Bar Charts
x = [1, 3, 5, 7, 9]
y = [3, 5, 2, 4, 6]

x2 = [2, 4, 6, 8, 10]
y2 = [4, 2, 3, 1, 5]

plt.bar(x, y, label='y', color='b')
plt.bar(x2, y2, label='y2', color='r')
plt.title('Bar charts')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
# Histogram:
mu, sigma,N = 0, 0.1, 1000 # mean, standard deviation and number of points
x = np.random.normal(mu,sigma,N)
bins = np.linspace(min(x), max(x),10, endpoint=False)
plt.hist(x,bins,histtype='bar',rwidth=0.8,normed=True)
plt.title('Histogram')
plt.xlabel('X')
plt.ylabel('P')
#plt.legend()
plt.show()

# %%
# Scatter:

x = [1, 2, 3, 3, 2, 5, 7, 6, 4]
y = [2, 5, 1, 4, 3, 2, 8, 7, 5]

plt.title('Scatter plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.scatter(x, y, label='y',marker='*',s=30) # s: marker size
plt.show()

# %%
# Stack:
x = [1, 2, 3, 4]
y1 = [3, 2, 4, 6]
y2 = [1, 1, 3, 4]
y3 = [2, 1, 2, 5]

plt.stackplot(x, y1,y2,y3, colors=['k','b','r'])

# create legend:
plt.plot([], [], color='k', label='y1', linewidth=5)
plt.plot([], [], color='b', label='y2', linewidth=5)
plt.plot([], [], color='r', label='y3', linewidth=5)

plt.title('Stack plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
# Multiple axis
# Plot y1 vs x on the left axis:
x = [1, 2, 3]
y1 = [3, 5, 2]
y2 = [4, -1., 3]

plt.xlabel("x")
plt.ylabel("y1", color="b")
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x, y1, "bo-", linewidth=2)

# Plot y2 vs x on the right axis:
plt.twinx()
plt.ylabel("y2", color="r")
plt.tick_params(axis="y", labelcolor="r")
plt.plot(x, y2, "r^--", linewidth=2)

plt.show()

# %%
# Display minor ticks:
# Plot y1 vs x on the left axis:
from matplotlib.ticker import AutoMinorLocator

x = [1, 2, 3]
y1 = [3, 5, 2]
y2 = [4, -1., 3]

ax = plt.subplot(1, 1, 1)
plt.xlabel("x")
plt.ylabel("y1", color="b")
ax.yaxis.set_minor_locator(AutoMinorLocator(5)) # minor ticks
plt.tick_params(axis="y", labelcolor="b")
plt.plot(x, y1, "bo-", linewidth=2)

# Plot y2 vs x on the right axis:
ax2 = plt.twinx()
plt.ylabel("y2", color="r")
plt.tick_params(axis="y", labelcolor="r")
ax2.yaxis.set_minor_locator(AutoMinorLocator(2)) # minor ticks
plt.plot(x, y2, "r^--", linewidth=2)

plt.show()

# %%
# multiple plots
x = [1, 2, 3]
y1 = [3, 5, 2]
y2 = [4, -1., 3]

fig, ax = plt.subplots(2, 2)
ax[0,0].scatter(x,y1)
ax[0,1].plot(x,y2)

plt.tight_layout(h_pad=0.5, w_pad=1)
plt.show()

# %%
# multiple plots
x = [1, 2, 3]
y1 = [3, 5, 2]
y2 = [4, -1., 3]
 
plt.subplot(2, 1, 1) # number of row, column, and figure index
plt.plot(x, y1, 'ko-')
plt.title('2 subplots')
plt.ylabel('neuron 1')

plt.subplot(2, 1, 2)
plt.plot(x, y2, 'b.-')
plt.xlabel('time (s)')
plt.ylabel('neuron 2')

plt.show()

# %%
# multiple plots
x = [1, 2, 3]
y1 = [3, 5, 2]
y2 = [4, -1., 3]
y3 = [2, -2., -1]
 
plt.subplot(2, 2, 1) # number of row, column, and figure index
plt.plot(x, y1, 'ko-')
plt.title('2 subplots')
plt.ylabel('neuron 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2, 'b.-')
plt.xlabel('time (s)')
plt.ylabel('neuron 2')

plt.subplot(2, 1, 2)
plt.plot(x, y3, 'r.--')
plt.xlabel('time (s)')
plt.ylabel('neuron 3')

plt.tight_layout(h_pad=0.5, w_pad=1)
plt.show()

# %%
x = np.random.rand(5,5)-0.5
y = np.random.rand(5,5)-0.5
plt.imshow(x,cmap='rainbow',interpolation='nearest',origin='lower') # origin = 'lower' to flip the image
plt.colorbar()
plt.clim(-1,1)
plt.show()

# %%
x = np.random.rand(5,5)-0.5
y = np.random.rand(5,5)-0.5
plt.imshow(x,cmap='gray',interpolation='nearest',origin='lower')
plt.colorbar()
plt.clim(-0.4, 0.4)
plt.show()

# %%
x = np.ones((5,2))
x[0,1]=-1
x[1,0]=-1
x[2,0]=-1
x[3,1]=-1
x[4,0]=-1

plt.imshow(x.T,cmap='gray_r',interpolation='nearest',origin='lower') # gray_r is invert of gray
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots(2, 3)

for i in range(2):
    for j in range(3):
        ax[i,j].scatter(np.random.normal(size=10), np.random.normal(size=10))

#ax[0,0].set_bounds

plt.tight_layout(h_pad=0, w_pad=0)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

nrow = 10
ncol = 3

fig = plt.figure(figsize=(4, 10)) 

gs = gridspec.GridSpec(nrow, ncol, width_ratios=[1, 1, 1],
         wspace=0.0, hspace=0.0, top=0.95, bottom=0.05, left=0.17, right=0.845) 

for i in range(10):
    for j in range(3):
        im = np.random.rand(28,28)
        ax= plt.subplot(gs[i,j])
        ax.imshow(im)
        ax.set_xticklabels([])
        ax.set_yticklabels([])

#plt.tight_layout() # do not use this!!
plt.show()
